# %% [markdown]
# ### Data and setup
# - Load cleaned REF datasets via shared helpers.
# - Prepare institutional/UoA aggregates for summaries and tests.

# %%
from pathlib import Path
import importlib
import sys
import pandas as pd

# Ensure local src/ is importable when run from the notebook
THIS_DIR = Path(__file__).resolve().parent if '__file__' in globals() else Path.cwd()
SRC_DIR = THIS_DIR if (THIS_DIR / 'statistics_summary.py').exists() else THIS_DIR / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.append(str(SRC_DIR))

import statistics_helpers
importlib.reload(statistics_helpers)
from statistics_helpers import (
    load_statistics_data,
    build_descriptive_summary,
    build_inference_summary,
    llm_female_share_tables,
    build_and_save_summary_tables,
)

pd.set_option('display.max_rows', 50)
pd.set_option('display.width', 200)

# Load raw and aggregated tables used across the summaries
df_output, df_ics, df_uoa_m, df_uni_m, df_uniuoa_m = load_statistics_data()

# %%
# Author-coverage share relative to the raw ICS submission count
data_root = (SRC_DIR / '..' / 'data').resolve()
raw_ics_path = '../data/final/enhanced_ref_data.csv'
raw_ics_total = len(pd.read_csv(raw_ics_path))
ics_with_authors = (df_ics[['number_male', 'number_female', 'number_unknown']].fillna(0).sum(axis=1) > 0).sum()
pct_with_authors = 100 * ics_with_authors / raw_ics_total if raw_ics_total else float('nan')

print(f"Raw ICS submissions: {raw_ics_total:,}")
print(f"ICS with author gender data: {ics_with_authors:,} ({pct_with_authors:.1f}% of raw ICS)")
print(f"ICS without author data: {raw_ics_total - ics_with_authors:,}")
# Out:
# Raw ICS submissions: 6,361
# ICS with author gender data: 6,310 (99.2% of raw ICS)
# ICS without author data: 51

# %%
# Author-coverage share relative to the raw REF outputs (Excel source)
raw_outputs_path = '../data/raw/raw_ref_outputs_data.xlsx'
raw_outputs_df = pd.read_excel(raw_outputs_path)
raw_output_total = len(raw_outputs_df)
outputs_with_authors = (df_output[['number_male', 'number_female', 'number_unknown']].fillna(0).sum(axis=1) > 0).sum()
pct_output_with_authors = 100 * outputs_with_authors / raw_output_total if raw_output_total else float('nan')

print(f"Raw REF outputs: {raw_output_total:,}")
print(f"Outputs with author gender data: {outputs_with_authors:,} ({pct_output_with_authors:.1f}% of raw outputs)")
print(f"Outputs without author data: {raw_output_total - outputs_with_authors:,}")
# Out:
# Raw REF outputs: 185,290
# Outputs with author gender data: 136,016 (73.4% of raw outputs)
# Outputs without author data: 49,274

# %%
# Female percentages by llm_* topics (ICS only)
llm_overall, llm_by_panel = llm_female_share_tables(df_ics)

print("Overall llm_* female shares (percent):")
display(llm_overall.assign(
    share_of_ics=lambda d: (d['share_of_ics'] * 100).round(2),
    pct_female=lambda d: (d['pct_female'] * 100).round(2),
))

print("\nllm_* female shares by REF panel (percent):")
display(llm_by_panel.assign(
    share_of_ics=lambda d: (d['share_of_ics'] * 100).round(2),
    pct_female=lambda d: (d['pct_female'] * 100).round(2),
))
# Out:
# Overall llm_* female shares (percent):
#         llm_topic  n_cases  share_of_ics  female  total_people  pct_female
# 0         Charity     1649         25.92    2124          4325       49.11
# 1      Drug Trial      454          7.14     502          1564       32.10
# 2        Heritage      982         15.44     867          1966       44.10
# 3     Legislation     1918         30.15    1978          4691       42.17
# 4   Manufacturing      916         14.40     591          2726       21.68
# 5          Museum      904         14.21     854          1839       46.44
# 6             Nhs     1230         19.34    1815          4004       45.33
# 7          Patent      374          5.88     210          1187       17.69
# 8          School     1600         25.15    1807          3935       45.92
# 9        Software     1690         26.57    1641          5060       32.43
# 10        Startup      801         12.59     577          2439       23.66
# llm_* female shares by REF panel (percent):
#         llm_topic  n_cases  share_of_ics  female  total_people  pct_female panel
# 0         Charity      435         30.66     799          1515       52.74     A
# 1      Drug Trial      347         24.45     431          1243       34.67     A
# 2        Heritage       30          2.11      21            66       31.82     A
# 3     Legislation      384         27.06     553          1168       47.35     A
# 4   Manufacturing      221         15.57     239           690       34.64     A
# 5          Museum       22          1.55      20            52       38.46     A
# 6             Nhs      730         51.44    1286          2651       48.51     A
# 7          Patent      122          8.60     104           370       28.11     A
# 8          School      196         13.81     284           539       52.69     A
# 9        Software      357         25.16     614          1278       48.04     A
# 10        Startup      181         12.76     201           598       33.61     A
# 11        Charity      132         10.41      99           410       24.15     B
# 12     Drug Trial       83          6.55      45           260       17.31     B
# 13       Heritage       58          4.57      47           191       24.61     B
# 14    Legislation      245         19.32     169           706       23.94     B
# 15  Manufacturing      531         41.88     206          1564       13.17     B
# 16         Museum       65          5.13      58           244       23.77     B
# 17            Nhs      138         10.88      88           449       19.60     B
# 18         Patent      223         17.59      82           721       11.37     B
# 19         School      166         13.09     137           607       22.57     B
# 20       Software      639         50.39     332          1947       17.05     B
# 21        Startup      403         31.78     178          1266       14.06     B
# 22        Charity      645         30.06     827          1598       51.75     C
# 23     Drug Trial       16          0.75      12            34       35.29     C
# 24       Heritage      174          8.11     173           408       42.40     C
# 25    Legislation     1056         49.21    1052          2365       44.48     C
# 26  Manufacturing      109          5.08      94           329       28.57     C
# 27         Museum      129          6.01     154           312       49.36     C
# 28            Nhs      237         11.04     309           640       48.28     C
# 29         Patent       18          0.84      13            62       20.97     C
# 30         School      522         24.32     735          1450       50.69     C
# 31       Software      412         19.20     400          1151       34.75     C
# 32        Startup      121          5.64     113           361       31.30     C
# 33        Charity      437         28.60     399           802       49.75     D
# 34     Drug Trial        8          0.52      14            27       51.85     D
# 35       Heritage      720         47.12     626          1301       48.12     D
# 36    Legislation      233         15.25     204           452       45.13     D
# 37  Manufacturing       55          3.60      52           143       36.36     D
# 38         Museum      688         45.03     622          1231       50.53     D
# 39            Nhs      125          8.18     132           264       50.00     D
# 40         Patent       11          0.72      11            34       32.35     D
# 41         School      716         46.86     651          1339       48.62     D
# 42       Software      282         18.46     295           684       43.13     D
# 43        Startup       96          6.28      85           214       39.72     D

# %% [markdown]
# ### Descriptive statistics
# High-level counts and top/bottom breakdowns for ICS vs Outputs, including panel-level and LLM topic summaries.

# %%
report = build_descriptive_summary(df_ics, df_uoa_m, df_uni_m, df_output)
print(report)
# Out:
# ============================================================
# DESCRIPTIVE SUMMARY OF FEMALE REPRESENTATION IN ICS & OUTPUTS
# ============================================================
#
# Overall female share:
#   • Outputs: 295,846.0 women / 854,366.0 total = 34.63% female
#   • ICS:     6,274 women / 16,447 total = 38.15% female
#
# All-female ICS submissions (excluding unknowns): 1,298 (20.41% of all ICS cases)
#
# LLM-tagged ICS cases (aggregate across all panels):
#     llm_topic  n_cases % of ICS  female  total_people % female
#       Charity     1649    25.92    2124          4325    49.11
#    Drug Trial      454     7.14     502          1564    32.10
#      Heritage      982    15.44     867          1966    44.10
#   Legislation     1918    30.15    1978          4691    42.17
# Manufacturing      916    14.40     591          2726    21.68
#        Museum      904    14.21     854          1839    46.44
#           Nhs     1230    19.34    1815          4004    45.33
#        Patent      374     5.88     210          1187    17.69
#        School     1600    25.15    1807          3935    45.92
#      Software     1690    26.57    1641          5060    32.43
#       Startup      801    12.59     577          2439    23.66
#
# LLM-tagged ICS cases by panel:
#     llm_topic  n_cases % of panel ICS  female  total_people % female panel
#       Charity      435          30.66     799          1515    52.74     A
#    Drug Trial      347          24.45     431          1243    34.67     A
#      Heritage       30           2.11      21            66    31.82     A
#   Legislation      384          27.06     553          1168    47.35     A
# Manufacturing      221          15.57     239           690    34.64     A
#        Museum       22           1.55      20            52    38.46     A
#           Nhs      730          51.44    1286          2651    48.51     A
#        Patent      122           8.60     104           370    28.11     A
#        School      196          13.81     284           539    52.69     A
#      Software      357          25.16     614          1278    48.04     A
#       Startup      181          12.76     201           598    33.61     A
#       Charity      132          10.41      99           410    24.15     B
#    Drug Trial       83           6.55      45           260    17.31     B
#      Heritage       58           4.57      47           191    24.61     B
#   Legislation      245          19.32     169           706    23.94     B
# Manufacturing      531          41.88     206          1564    13.17     B
#        Museum       65           5.13      58           244    23.77     B
#           Nhs      138          10.88      88           449    19.60     B
#        Patent      223          17.59      82           721    11.37     B
#        School      166          13.09     137           607    22.57     B
#      Software      639          50.39     332          1947    17.05     B
#       Startup      403          31.78     178          1266    14.06     B
#       Charity      645          30.06     827          1598    51.75     C
#    Drug Trial       16           0.75      12            34    35.29     C
#      Heritage      174           8.11     173           408    42.40     C
#   Legislation     1056          49.21    1052          2365    44.48     C
# Manufacturing      109           5.08      94           329    28.57     C
#        Museum      129           6.01     154           312    49.36     C
#           Nhs      237          11.04     309           640    48.28     C
#        Patent       18           0.84      13            62    20.97     C
#        School      522          24.32     735          1450    50.69     C
#      Software      412          19.20     400          1151    34.75     C
#       Startup      121           5.64     113           361    31.30     C
#       Charity      437          28.60     399           802    49.75     D
#    Drug Trial        8           0.52      14            27    51.85     D
#      Heritage      720          47.12     626          1301    48.12     D
#   Legislation      233          15.25     204           452    45.13     D
# Manufacturing       55           3.60      52           143    36.36     D
#        Museum      688          45.03     622          1231    50.53     D
#           Nhs      125           8.18     132           264    50.00     D
#        Patent       11           0.72      11            34    32.35     D
#        School      716          46.86     651          1339    48.62     D
#      Software      282          18.46     295           684    43.13     D
#       Startup       96           6.28      85           214    39.72     D
#
# Female share by REF main panel (aggregated across UoAs):
#   Panel A: Outputs 198,941/499,422 = 39.83% | ICS 2,136/4,696 = 45.49%
#   Panel B: Outputs 37,063/193,772 = 19.13% | ICS 682/3,773 = 18.08%
#   Panel C: Outputs 49,588/138,193 = 35.88% | ICS 2,169/5,201 = 41.70%
#   Panel D: Outputs 10,254/22,979 = 44.62% | ICS 1,287/2,777 = 46.34%
#
# All-female ICS submissions by panel:
#   Panel A: 247 (17.41% of 1,419 ICS cases)
#   Panel B: 70 (5.52% of 1,268 ICS cases)
#   Panel C: 473 (22.04% of 2,146 ICS cases)
#   Panel D: 508 (33.25% of 1,528 ICS cases)
# Universities with highest female Impact (ICS) proportions:
#                     Institution name  pct_female_ics  pct_female_output
#       Stranmillis University College        1.000000           0.741379
#               Royal College of Music        0.800000           0.622642
#                Leeds Arts University        0.750000           0.636364
# Queen Margaret University, Edinburgh        0.714286           0.624060
#           Courtauld Institute of Art        0.714286           0.750000
#
# Universities with lowest female Impact (ICS) proportions:
#                                Institution name  pct_female_ics  pct_female_output
#               Guildhall School of Music & Drama        0.000000           0.200000
# Rose Bruford College of Theatre and Performance        0.000000           0.400000
#  Trinity Laban Conservatoire of Music and Dance        0.000000           0.692308
#                  Solent University, Southampton        0.166667           0.434932
#                             Falmouth University        0.176471           0.335714
#
# Universities with largest positive difference (ICS − Output):
#                 Institution name  pct_female_ics  pct_female_output  diff_ics_output
#              Hartpury University        0.600000           0.263158         0.336842
#   Stranmillis University College        1.000000           0.741379         0.258621
#   Ravensbourne University London        0.500000           0.290323         0.209677
#              Coventry University        0.508333           0.324205         0.184128
# Arts University Bournemouth, the        0.600000           0.416667         0.183333
#
# Universities with largest negative difference (ICS − Output):
#                                Institution name  pct_female_ics  pct_female_output  diff_ics_output
#  Trinity Laban Conservatoire of Music and Dance        0.000000           0.692308        -0.692308
#    The Royal Central School of Speech and Drama        0.200000           0.647059        -0.447059
#                  Norwich University of the Arts        0.333333           0.758621        -0.425287
# Rose Bruford College of Theatre and Performance        0.000000           0.400000        -0.400000
#                University for the Creative Arts        0.333333           0.692308        -0.358974
#
# UoAs with highest female Impact (ICS) proportions:
#                                    Unit of assessment name  pct_female_ics  pct_female_output
#                              Social Work and Social Policy        0.573214           0.550682
#                            English Language and Literature        0.571429           0.520712
# Allied Health Professions, Dentistry, Nursing and Pharmacy        0.569648           0.436160
#                                                  Sociology        0.560000           0.505938
#                                                  Education        0.559249           0.554142
#
# UoAs with lowest female Impact (ICS) proportions:
#          Unit of assessment name  pct_female_ics  pct_female_output
#                          Physics        0.143573           0.090683
#                      Engineering        0.157591           0.205298
# Computer Science and Informatics        0.160428           0.196051
#                        Chemistry        0.185811           0.251420
#       Economics and Econometrics        0.230769           0.207314
#
# UoAs with largest positive difference (ICS − Output):
#                                    Unit of assessment name  pct_female_ics  pct_female_output  diff_ics_output
#                    Psychology, Psychiatry and Neuroscience        0.544950           0.410258         0.134692
# Allied Health Professions, Dentistry, Nursing and Pharmacy        0.569648           0.436160         0.133488
#                                                        Law        0.536524           0.418484         0.118040
#                                                   Classics        0.531646           0.418259         0.113387
#                                                 Philosophy        0.346405           0.247893         0.098512
#
# UoAs with largest negative difference (ICS − Output):
#                                       Unit of assessment name  pct_female_ics  pct_female_output  diff_ics_output
#                                             Clinical Medicine        0.306054           0.388782        -0.082728
#                                           Biological Sciences        0.276639           0.352988        -0.076349
#                                                     Chemistry        0.185811           0.251420        -0.065609
# Music, Drama, Dance, Performing Arts, Film and Screen Studies        0.404389           0.460476        -0.056087
#                                                   Engineering        0.157591           0.205298        -0.047708
#
# Panel-specific UoA breakdowns:
#
# Panel A:
#   UoAs with highest female Impact (ICS) proportions:
#                                    Unit of assessment name  pct_female_ics  pct_female_output
# Allied Health Professions, Dentistry, Nursing and Pharmacy        0.569648           0.436160
#                    Psychology, Psychiatry and Neuroscience        0.544950           0.410258
#            Public Health, Health Services and Primary Care        0.476965           0.418231
#                  Agriculture, Food and Veterinary Sciences        0.345048           0.363120
#                                          Clinical Medicine        0.306054           0.388782
#   UoAs with lowest female Impact (ICS) proportions:
#                         Unit of assessment name  pct_female_ics  pct_female_output
#                             Biological Sciences        0.276639           0.352988
#                               Clinical Medicine        0.306054           0.388782
#       Agriculture, Food and Veterinary Sciences        0.345048           0.363120
# Public Health, Health Services and Primary Care        0.476965           0.418231
#         Psychology, Psychiatry and Neuroscience        0.544950           0.410258
#   UoAs with largest positive difference (ICS − Output):
#                                    Unit of assessment name  pct_female_ics  pct_female_output  diff_ics_output
#                    Psychology, Psychiatry and Neuroscience        0.544950           0.410258         0.134692
# Allied Health Professions, Dentistry, Nursing and Pharmacy        0.569648           0.436160         0.133488
#            Public Health, Health Services and Primary Care        0.476965           0.418231         0.058734
#                  Agriculture, Food and Veterinary Sciences        0.345048           0.363120        -0.018072
#                                        Biological Sciences        0.276639           0.352988        -0.076349
#   UoAs with largest negative difference (ICS − Output):
#                                    Unit of assessment name  pct_female_ics  pct_female_output  diff_ics_output
#                                          Clinical Medicine        0.306054           0.388782        -0.082728
#                                        Biological Sciences        0.276639           0.352988        -0.076349
#                  Agriculture, Food and Veterinary Sciences        0.345048           0.363120        -0.018072
#            Public Health, Health Services and Primary Care        0.476965           0.418231         0.058734
# Allied Health Professions, Dentistry, Nursing and Pharmacy        0.569648           0.436160         0.133488
#   Summary statistics (Impact) for pct female across UoAs:
# count    6.000
# mean     0.420
# std      0.127
# min      0.277
# 25%      0.316
# 50%      0.411
# 75%      0.528
# max      0.570
#   Summary statistics (Outputs) for pct female across UoAs:
# count    6.000
# mean     0.395
# std      0.033
# min      0.353
# 25%      0.370
# 50%      0.400
# 75%      0.416
# max      0.436
#
# Panel B:
#   UoAs with highest female Impact (ICS) proportions:
#                  Unit of assessment name  pct_female_ics  pct_female_output
# Earth Systems and Environmental Sciences        0.261044           0.278694
#                    Mathematical Sciences        0.238095           0.194792
#                                Chemistry        0.185811           0.251420
#         Computer Science and Informatics        0.160428           0.196051
#                              Engineering        0.157591           0.205298
#   UoAs with lowest female Impact (ICS) proportions:
#          Unit of assessment name  pct_female_ics  pct_female_output
#                          Physics        0.143573           0.090683
#                      Engineering        0.157591           0.205298
# Computer Science and Informatics        0.160428           0.196051
#                        Chemistry        0.185811           0.251420
#            Mathematical Sciences        0.238095           0.194792
#   UoAs with largest positive difference (ICS − Output):
#                  Unit of assessment name  pct_female_ics  pct_female_output  diff_ics_output
#                                  Physics        0.143573           0.090683         0.052890
#                    Mathematical Sciences        0.238095           0.194792         0.043303
# Earth Systems and Environmental Sciences        0.261044           0.278694        -0.017650
#         Computer Science and Informatics        0.160428           0.196051        -0.035623
#                              Engineering        0.157591           0.205298        -0.047708
#   UoAs with largest negative difference (ICS − Output):
#                  Unit of assessment name  pct_female_ics  pct_female_output  diff_ics_output
#                                Chemistry        0.185811           0.251420        -0.065609
#                              Engineering        0.157591           0.205298        -0.047708
#         Computer Science and Informatics        0.160428           0.196051        -0.035623
# Earth Systems and Environmental Sciences        0.261044           0.278694        -0.017650
#                    Mathematical Sciences        0.238095           0.194792         0.043303
#   Summary statistics (Impact) for pct female across UoAs:
# count    6.000
# mean     0.191
# std      0.048
# min      0.144
# 25%      0.158
# 50%      0.173
# 75%      0.225
# max      0.261
#   Summary statistics (Outputs) for pct female across UoAs:
# count    6.000
# mean     0.203
# std      0.065
# min      0.091
# 25%      0.195
# 50%      0.201
# 75%      0.240
# max      0.279
#
# Panel C:
#   UoAs with highest female Impact (ICS) proportions:
#              Unit of assessment name  pct_female_ics  pct_female_output
#        Social Work and Social Policy        0.573214           0.550682
#                            Sociology        0.560000           0.505938
#                            Education        0.559249           0.554142
#                                  Law        0.536524           0.418484
# Anthropology and Development Studies        0.460432           0.411852
#   UoAs with lowest female Impact (ICS) proportions:
#                          Unit of assessment name  pct_female_ics  pct_female_output
#                       Economics and Econometrics        0.230769           0.207314
#     Architecture, Built Environment and Planning        0.286863           0.295996
# Sport and Exercise Sciences, Leisure and Tourism        0.318533           0.326871
#              Geography and Environmental Studies        0.341509           0.294821
#                  Business and Management Studies        0.343537           0.311484
#   UoAs with largest positive difference (ICS − Output):
#              Unit of assessment name  pct_female_ics  pct_female_output  diff_ics_output
#                                  Law        0.536524           0.418484         0.118040
#                            Sociology        0.560000           0.505938         0.054062
# Anthropology and Development Studies        0.460432           0.411852         0.048579
#  Geography and Environmental Studies        0.341509           0.294821         0.046689
#   Politics and International Studies        0.365248           0.332882         0.032366
#   UoAs with largest negative difference (ICS − Output):
#                          Unit of assessment name  pct_female_ics  pct_female_output  diff_ics_output
#     Architecture, Built Environment and Planning        0.286863           0.295996        -0.009133
# Sport and Exercise Sciences, Leisure and Tourism        0.318533           0.326871        -0.008338
#                                        Education        0.559249           0.554142         0.005107
#                                      Archaeology        0.391566           0.373005         0.018561
#                    Social Work and Social Policy        0.573214           0.550682         0.022533
#   Summary statistics (Impact) for pct female across UoAs:
# count    12.000
# mean      0.414
# std       0.119
# min       0.231
# 25%       0.336
# 50%       0.378
# 75%       0.542
# max       0.573
#   Summary statistics (Outputs) for pct female across UoAs:
# count    12.000
# mean      0.382
# std       0.109
# min       0.207
# 25%       0.308
# 50%       0.353
# 75%       0.440
# max       0.554
#
# Panel D:
#   UoAs with highest female Impact (ICS) proportions:
#                                                       Unit of assessment name  pct_female_ics  pct_female_output
#                                               English Language and Literature        0.571429           0.520712
#                                              Modern Languages and Linguistics        0.538462           0.546992
#                                                                      Classics        0.531646           0.418259
# Communication, Cultural and Media Studies, Library and Information Management        0.511194           0.446368
#                                                                  Area Studies        0.511111           0.451140
#   UoAs with lowest female Impact (ICS) proportions:
#                                       Unit of assessment name  pct_female_ics  pct_female_output
#                                Theology and Religious Studies        0.339450           0.339688
#                                                    Philosophy        0.346405           0.247893
#                                                       History        0.366667           0.369799
# Music, Drama, Dance, Performing Arts, Film and Screen Studies        0.404389           0.460476
#                  Art and Design: History, Practice and Theory        0.437393           0.460257
#   UoAs with largest positive difference (ICS − Output):
#                                                       Unit of assessment name  pct_female_ics  pct_female_output  diff_ics_output
#                                                                      Classics        0.531646           0.418259         0.113387
#                                                                    Philosophy        0.346405           0.247893         0.098512
# Communication, Cultural and Media Studies, Library and Information Management        0.511194           0.446368         0.064826
#                                                                  Area Studies        0.511111           0.451140         0.059971
#                                               English Language and Literature        0.571429           0.520712         0.050716
#   UoAs with largest negative difference (ICS − Output):
#                                       Unit of assessment name  pct_female_ics  pct_female_output  diff_ics_output
# Music, Drama, Dance, Performing Arts, Film and Screen Studies        0.404389           0.460476        -0.056087
#                  Art and Design: History, Practice and Theory        0.437393           0.460257        -0.022864
#                              Modern Languages and Linguistics        0.538462           0.546992        -0.008531
#                                                       History        0.366667           0.369799        -0.003132
#                                Theology and Religious Studies        0.339450           0.339688        -0.000239
#   Summary statistics (Impact) for pct female across UoAs:
# count    10.000
# mean      0.456
# std       0.087
# min       0.339
# 25%       0.376
# 50%       0.474
# 75%       0.527
# max       0.571
#   Summary statistics (Outputs) for pct female across UoAs:
# count    10.000
# mean      0.426
# std       0.088
# min       0.248
# 25%       0.382
# 50%       0.449
# 75%       0.460
# max       0.547
#
# Average female share by Discipline group (STEM vs SHAPE):
#                   pct_female_ics  pct_female_output   diff
# Discipline_group
# SHAPE                      0.438              0.402  0.035
# STEM                       0.284              0.289 -0.005
#
# Summary statistics of female proportions across Universities and UoAs:
# Universities (Impact):
# count    155.000
# mean       0.404
# std        0.132
# min        0.000
# 25%        0.333
# 50%        0.400
# 75%        0.465
# max        1.000
#
# UoAs (Impact):
# count    34.000
# mean      0.388
# std       0.136
# min       0.144
# 25%       0.292
# 50%       0.366
# 75%       0.527
# max       0.573
#
# Universities (Outputs):
# count    157.000
# mean       0.393
# std        0.102
# min        0.200
# 25%        0.334
# 50%        0.370
# 75%        0.407
# max        0.759
#
# UoAs (Outputs):
# count    34.000
# mean      0.366
# std       0.114
# min       0.091
# 25%       0.295
# 50%       0.371
# 75%       0.444
# max       0.554

# %% [markdown]
# ### Inference: ICS vs Outputs
# One-sided tests asking whether female share in ICS exceeds Outputs at multiple levels.

# %%
inference_report = build_inference_summary(df_ics, df_output, df_uoa_m, df_uni_m, df_uniuoa_m)
print(inference_report)
# Out:
# Hypothesis across all levels: female proportion in ICS exceeds Outputs (one-sided tests).
#
# RAW pooled female shares:
#   ICS   : p̂ = 0.3815  (95% CI [0.3740, 0.3889]), n = 16447
#   Output: p̂ = 0.3463  (95% CI [0.3453, 0.3473]), n = 854366
#
# Two-proportion z-test (RAW):
#   H0: p_ICS = p_Output   vs   H1: p_ICS > p_Output
#   z = 9.392, p = 0 (H0: p1 = p2 vs H1: p1 > p2). Observed difference p1−p2 = +0.0352 [+0.0277, +0.0427] (95% CI, Wald, unpooled). Result is statistically significant at α=0.05; the estimated difference is positive.
#   Interpretation: This tests the overall female share across all observations. A significant result supports higher ICS share.
#
#
# — University level: paired analysis for Δ = (ICS − Output)
#   Descriptives: n = 155, mean(Δ) = 0.0105 (95% CI [-0.0096, 0.0305]), sd = 0.1273, Cohen's dz = 0.082
#   t-test (mean Δ > 0): t = 1.023, p = 0.154 → not significant at α=0.05 (mean Δ positive).
#   Wilcoxon (median Δ > 0): W = 7525.000, p = 0.0041 → significant (median Δ positive).
#   Sign test (P(Δ>0) > 0.5): positives = 89/155 (57.419%), p = 0.0384 → significant.
#   Interpretation: Positive, significant results indicate universities tend to have higher female shares in ICS than in Outputs.
#
#
# — Unit of Assessment (UoA) level: paired analysis for Δ = (ICS − Output)
#   Descriptives: n = 34, mean(Δ) = 0.0224 (95% CI [0.0029, 0.0418]), sd = 0.0577, Cohen's dz = 0.387
#   t-test (mean Δ > 0): t = 2.257, p = 0.0154 → significant at α=0.05 (mean Δ positive).
#   Wilcoxon (median Δ > 0): W = 411.000, p = 0.0263 → significant (median Δ positive).
#   Sign test (P(Δ>0) > 0.5): positives = 20/34 (58.824%), p = 0.196 → not significant.
#   Interpretation: Positive, significant results indicate disciplines (UoAs) tend to have higher female shares in ICS.
#
#
# — Institution × UoA level: paired analysis for Δ = (ICS − Output)
#   Descriptives: n = 1833, mean(Δ) = 0.0082 (95% CI [-0.0032, 0.0195]), sd = 0.2483, Cohen's dz = 0.033
#   t-test (mean Δ > 0): t = 1.408, p = 0.0796 → not significant at α=0.05 (mean Δ positive).
#   Wilcoxon (median Δ > 0): W = 820820.500, p = 0.411 → not significant (median Δ zero).
#   Sign test (P(Δ>0) > 0.5): positives = 895/1806 (49.557%), p = 0.655 → not significant.
#   Interpretation: At the cell level, a significant positive Δ indicates the tendency persists at finer granularity.
#
# RECAP:
#   • RAW z-test asks: Is the *overall* female share higher in ICS than in Outputs?
#   • Paired tests (University, UoA, and Inst×UoA) ask: Within each unit, is ICS share higher than Outputs (Δ>0)?
#   • Convergent significance across multiple tests provides robust evidence that female ICS contribution exceeds Output.

# %% [markdown]
# ### LaTeX summary tables
# Save panel, UoA, and LLM topic tables; print them and note the output path.

# %%
# Build and save LaTeX tables
tables_out_dir = Path('../outputs/tables')
tables = build_and_save_summary_tables(df_ics, df_output, out_dir=tables_out_dir)
print(f'Saved LaTeX tables to: {tables_out_dir.resolve()}')
print('Files:')
for p in sorted(tables_out_dir.glob('*.tex')):
    print(' -', p.name)

print('Panel summary (ICS vs Outputs):', display(tables['panel']))
 
print('UoA summary (ICS vs Outputs):', display(tables['uoa']))

print('LLM topics (aggregate, ICS only):', display(tables['llm']))

print('LLM topics by Panel (ICS only):', display(tables['llm_panel']))
# Out:
# Saved LaTeX tables to: /home/porco/Dropbox/ics_work/ref_gender/outputs/tables
# Files:
#  - llm_panel_summary.tex
#  - llm_summary.tex
#  - panel_summary.tex
#  - regression_results.tex
#  - uoa_summary.tex
#   Panel     FTE  PhDs (000)  Total Income (£bn)  N (ICS)  % Female (ICS)  % All Female (ICS)  N (Papers)  % Female (Papers)  % All Female (Papers)
# 0     A  149915         366             232.700     1419           45.49               34.05       41253              39.83                 67.240
# 1     B   98047         311             104.800     1268           18.08               10.87       33953              19.13                 12.530
# 2     C  110106         174              17.700     2146           41.70               34.57       44770              35.88                 16.760
# 3     D   54291          88               5.305     1528           46.34               20.51       16040              44.62                  3.466
# Panel summary (ICS vs Outputs): None
#     UoA                                 Unit of Assessment Panel    FTE  PhDs (000)  Total Income (£bn)  N (ICS)  % Female (ICS)  % All Female (ICS)  N (Papers)  % Female (Papers)  \
# 0     1                                  Clinical Medicine     A  53711         134            127.8000      254           30.61              4.3510        9309             38.880
# 1     2    Public Health, Health Services and Primary Care     A  15662          20             26.0800      151           47.70              5.6100        3525             41.820
# 2     3  Allied Health Professions, Dentistry, Nursing ...     A  28252          60             12.1300      393           56.96             12.3800       10093             43.620
# 3     4            Psychology, Psychiatry and Neuroscience     A  25203          71             28.5600      326           54.50              7.8260        8609             41.030
# 4     5                                Biological Sciences     A  18968          64             30.7900      192           27.66              2.1520        6520             35.300
# 5     6          Agriculture, Food and Veterinary Sciences     A   8119          18              7.3050      103           34.50              1.7210        3197             36.310
# 6     7           Earth Systems and Environmental Sciences     B   8510          20              6.9560      148           26.10              2.0720        3816             27.870
# 7     8                                          Chemistry     B   4834          25              6.8940      113           18.58              0.8766        3350             25.140
# 8     9                                            Physics     B  11330          34             20.8800      169           14.36              1.3710        3481              9.068
# 9    10                              Mathematical Sciences     B  10814          21              3.4510      176           23.81              1.5940        4302             19.480
# 10   11                   Computer Science and Informatics     B  11418          26              6.1980      271           16.04              1.9130        4844             19.610
# 11   12                                        Engineering     B  51141         186             60.4100      391           15.76              3.0440       14160             20.530
# 12   13       Architecture, Built Environment and Planning     C   7844          12              1.8830      127           28.69              1.7050        2809             29.600
# 13   14                Geography and Environmental Studies     C   7292          12              2.5630      180           34.15              2.8850        3872             29.480
# 14   15                                        Archaeology     C   1495           4              0.6931       59           39.16              1.0360         771             37.300
# 15   16                         Economics and Econometrics     C   3655           6              0.9054       88           23.08              0.5260        1909             20.730
# 16   17                    Business and Management Studies     C  42385          55              3.4840      504           34.35              6.4390       14297             31.150
# 17   18                                                Law     C  10734          14              0.8315      226           53.65              3.3950        3553             41.850
# 18   19                 Politics and International Studies     C   7489          13              1.2250      166           36.52              1.6420        3376             33.290
# 19   20                      Social Work and Social Policy     C   7708          10              1.5220      222           57.32              5.1160        3842             55.070
# 20   21                                          Sociology     C   3728           7              1.0130      107           56.00              2.0080        1959             50.590
# 21   22               Anthropology and Development Studies     C   2452           6              0.7696       77           46.04              1.0200        1309             41.190
# 22   23                                          Education     C  10342          27              2.2720      230           55.92              6.1680        4030             55.410
# 23   24   Sport and Exercise Sciences, Leisure and Tourism     C   4981           7              0.5365      160           31.85              2.6300        3043             32.690
# 24   25                                       Area Studies     D   1844           3              0.2689       57           51.11              0.7332         830             45.110
# 25   26                   Modern Languages and Linguistics     D   7115          13              0.7534      154           53.85              2.6780        2094             54.700
# 26   27                    English Language and Literature     D  10146          18              0.6060      273           57.14              4.5900        2487             52.070
# 27   28                                            History     D   9962          18              1.1710      240           36.67              2.1040        3187             36.980
# 28   29                                           Classics     D   1632           3              0.2348       48           53.16              0.6694         317             41.830
# 29   30                                         Philosophy     D   2433           4              0.4666       85           34.64              0.8448        1182             24.790
# 30   31                     Theology and Religious Studies     D   1340           5              0.1431       68           33.94              0.5897         518             33.970
# 31   32       Art and Design: History, Practice and Theory     D  12072          13              1.1240      262           43.74              4.0640        2034             46.030
# 32   33  Music, Drama, Dance, Performing Arts, Film and...     D   3837           6              0.2466      196           40.44              2.0560        1478             46.050
# 33   34  Communication, Cultural and Media Studies, Lib...     D   3910           5              0.2900      145           51.12              2.1840        1913             44.640
#
#     % All Female (Papers)
# 0                23.06000
# 1                 9.36700
# 2                12.85000
# 3                10.98000
# 4                 7.79500
# 5                 3.19800
# 6                 3.21100
# 7                 2.03600
# 8                 1.61500
# 9                 0.73590
# 10                1.19500
# 11                3.73500
# 12                0.77710
# 13                2.66900
# 14                0.72670
# 15                0.30660
# 16                3.93000
# 17                0.68110
# 18                0.66450
# 19                2.00700
# 20                0.69120
# 21                0.46750
# 22                2.01700
# 23                1.82400
# 24                0.18730
# 25                0.59020
# 26                0.51410
# 27                0.45360
# 28                0.06659
# 29                0.11930
# 30                0.06625
# 31                0.65370
# 32                0.32690
# 33                0.48810
# UoA summary (ICS vs Outputs): None
#             Topic  Number of ICS  % Female Authors  % of All Female Authors
# 0         Charity           1649         49.109827                33.854001
# 1         Startup            801         23.657237                 9.196685
# 2          Patent            374         17.691660                 3.347147
# 3          Museum            904         46.438282                13.611731
# 4             Nhs           1230         45.329670                28.928913
# 5      Drug Trial            454         32.097187                 8.001275
# 6          School           1600         45.921220                28.801403
# 7     Legislation           1918         42.165849                31.526937
# 8        Heritage            982         44.099695                13.818935
# 9   Manufacturing            916         21.680117                 9.419828
# 10       Software           1690         32.430830                26.155563
# LLM topics (aggregate, ICS only): None
#    Panel          Topic  Number of ICS  % Female Authors  % of All Female Authors (panel)
# 0      A        Charity            435         52.739274                        37.406367
# 1      A        Startup            181         33.612040                         9.410112
# 2      A         Patent            122         28.108108                         4.868914
# 3      A         Museum             22         38.461538                         0.936330
# 4      A            Nhs            730         48.509996                        60.205993
# 5      A     Drug Trial            347         34.674175                        20.177903
# 6      A         School            196         52.690167                        13.295880
# 7      A    Legislation            384         47.345890                        25.889513
# 8      A       Heritage             30         31.818182                         0.983146
# 9      A  Manufacturing            221         34.637681                        11.189139
# 10     A       Software            357         48.043818                        28.745318
# 11     B        Charity            132         24.146341                        14.516129
# 12     B        Startup            403         14.060032                        26.099707
# 13     B         Patent            223         11.373093                        12.023460
# 14     B         Museum             65         23.770492                         8.504399
# 15     B            Nhs            138         19.599109                        12.903226
# 16     B     Drug Trial             83         17.307692                         6.598240
# 17     B         School            166         22.570016                        20.087977
# 18     B    Legislation            245         23.937677                        24.780059
# 19     B       Heritage             58         24.607330                         6.891496
# 20     B  Manufacturing            531         13.171355                        30.205279
# 21     B       Software            639         17.051875                        48.680352
# 22     C        Charity            645         51.752190                        38.128170
# 23     C        Startup            121         31.301939                         5.209774
# 24     C         Patent             18         20.967742                         0.599355
# 25     C         Museum            129         49.358974                         7.100046
# 26     C            Nhs            237         48.281250                        14.246196
# 27     C     Drug Trial             16         35.294118                         0.553250
# 28     C         School            522         50.689655                        33.886584
# 29     C    Legislation           1056         44.482030                        48.501614
# 30     C       Heritage            174         42.401961                         7.976026
# 31     C  Manufacturing            109         28.571429                         4.333794
# 32     C       Software            412         34.752389                        18.441678
# 33     D        Charity            437         49.750623                        31.002331
# 34     D        Startup             96         39.719626                         6.604507
# 35     D         Patent             11         32.352941                         0.854701
# 36     D         Museum            688         50.528026                        48.329448
# 37     D            Nhs            125         50.000000                        10.256410
# 38     D     Drug Trial              8         51.851852                         1.087801
# 39     D         School            716         48.618372                        50.582751
# 40     D    Legislation            233         45.132743                        15.850816
# 41     D       Heritage            720         48.116833                        48.640249
# 42     D  Manufacturing             55         36.363636                         4.040404
# 43     D       Software            282         43.128655                        22.921523
# LLM topics by Panel (ICS only): None
